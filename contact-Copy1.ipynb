# %% [markdown]
# # Contact Book Management

# %%
# open contact
# search contact
# add contact 
# update name and number 
# delete contact 
# 0 for back to menu

# %%
import numpy as np
import pandas as pd
try:
    contact_data = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
    contact_data.drop('Unnamed: 0',axis=1,inplace=True)
except:
    di = [{'Name': "Akshat",'Number':'1','Number1':'2','Number2':'3','Email':'Abc@123','NickName':'Akku'}]
    contact_data = pd.DataFrame(di)

# %%
def add_details():
    
    while 1:
        
        print("\nAdd Details")
        a = input("Name:").title()
        b = input("\nNumber: ").title()   # number 1
        if contact_data[contact_data.Number == b ]:
            print('''Number already exist 
            Press 1 to Update Name
            Press 2 For Other Number''')
            print(contact_data[contact_data.Number == b ])
            input12 = int(input('\nOption: '))
            if input12 == 1:
                n = (contact_data[contact_data.Number == b ])
                y= list(n.index)
                new = input('Enter new number: ')
                contact_data['Number'].loc[y] = new
            elif input12 ==2:
                b = input("Number: ")   # number 1
                
            else:
                print('''Thank you!!!
                       Back to Menu''')
                return

        print('''Want more number press Y/N''')
        want_num = input().title()
        if want_num == 'Y':
            c = input("Number1: ")
        else:
            c = np.nan

        print('''Want more number press Y/N''')
        want_num1 = input().title()
        if want_num1 == 'Y':
            d = input("Number2: ")
        else:
            d = np.nan    # this will give null value (Nan)

        e = input("Email: ").title()
        f = input("NickName: ").title()
        dic = dict(zip(contact_data.columns,[a,b,c,d,e,f]))
        contact_data.loc[len(contact_data)] = [a,b,c,d,e,f]

        print('\nSuccessful','\n',contact_data)

        #     here its for the end or go back to menu
        print('''
                Press 1 to Retry 
                Press 2 to go back to Menu''')

        input12 = int(input("\nOption: "))
        if input12 == 1:
            continue           # to return to same function 
        if input12 == 2:
            print('Thank you!!!')
            return             # to return to menu function
        
# add_details()

# %%
def search_data():
    
    while 1:
        
        print('''Search on the basis of
        Name     Press 1
        Number   Press 2
        Email    Press 3
        NickName Press 4''')
        num = int(input("Option: "))
        if num == 1:
            name1 = input("\nName: ").title()
            print("\n")
            print(contact_data[contact_data.Name == name1 ])

            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return           

        elif num == 2:
            name1 = input("\nNumber: ").title()
            print("\n")
            print(contact_data[contact_data.Number == name1 ])
            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return

        elif num == 3:
            name1 = input("\nEmail: ").title()
            print("\n")
            print(contact_data[contact_data.Email == name1 ])

            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return
                
        elif num == 4:
            name1 = input("\nNickName: ").title()
            print("\n")
            print(contact_data[contact_data.NickName == name1 ]) 

            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return

        else:
            print('''
            .....Invalid input......
            ....Please try Again.... ''')
            print('')
            print('''
                Press 1 to Retry 
                Press 2 to go back to Menu''')

            input12 = int(input("\nOption: "))
            if input12 == 1:
                continue           # to return to same function 
            if input12 == 2:
                print('Thank you!!!')
                return             # to return to menu function 
            
# search_data()

# %%
def delete_data():
    
    while 1: 
        print('''Delete on the basis of
                Name Press 1
                Number Press 2
                Email Press 3
                NickName Press 4''')
        num = int(input("Option: "))
        if num == 1:
            name1 = input("\nName: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            contact_data.drop(index = y , inplace = True)
            print('successfully Done')
            print(contact_data)
            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return

        elif num == 2:
            name1 = input("\nNumber: ").title()
            print("\n")
            n = (contact_data[contact_data.Number == name1 ])
            y= list(n.index)
            contact_data.drop(index = y , inplace = True)
            print('successfully Done')
            print(contact_data)
            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return

        elif num == 3:
            name1 = input("\nEmail: ").title()
            print("\n")
            n = contact_data[contact_data.Email == name1 ]
            y= list(n.index)
            contact_data.drop(index = y , inplace = True)
            print('successfully Done')
            print(contact_data)
            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return
                
        elif num == 4:
            name1 = input("\nNickName: ").title()
            print("\n")
            n = (contact_data[contact_data.NickName == name1 ]) 
            y= list(n.index)
            contact_data.drop(index = y , inplace = True)
            print('successfully Done')
            print(contact_data)
            
            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return
        else:
            print('''
            .....Invalid input......
            .....Please try Again.... ''')
            print('')
            print('''
                Press 1 to Retry 
                Press 2 to go back to Menu''')

            input12 = int(input("\nOption: "))
            if input12 == 1:
                continue           # to return to same function 
            if input12 == 2:
                print('Thank you!!!')
                return             # to return to menu function

# %%
def update_numbers():
    
    while True:
        
        print('''Press 1 to update number 1
        Press 2 to update number 2
        Press 3 to update number 3''')
        num2 = int(input('Option: '))
        if num2 == 1:
            name1 = input("\nEnter Person Name: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            new = input('Enter new number: ')
            contact_data['Number'].loc[y] = new

            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return

        elif num2 == 2:
            name1 = input("\nEnter Person Name: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            new = input('Enter new number: ')
            contact_data['Number1'].loc[y] = new

            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return

        elif num2 == 3:
            name1 = input("\nEnter Person Name: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            new = input('Enter new number: ')
            contact_data['Number2'].loc[y] = new

            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return
        else:
            print('''
            .....Invalid input......
            .....Please try Again.... ''')
            print('')
            print('''
                Press 1 to Retry 
                Press 2 to go back to Menu''')

            input12 = int(input("\nOption: "))
            if input12 == 1:
                continue           # to return to same function 
            if input12 == 2:
                print('Thank you!!!')
                return             # to return to menu function

# %%
def update_data():
    
    while True:
        
        print('''To Update Data of 
        Name     Press 1
        Number   Press 2
        Email    Press 3
        NickName Press 4''')
        num1 = int(input("Option: "))

        if num1 == 1:

            name1 = input("\nName: ").title()
            print("\n")
            n = (contact_data[contact_data.Name == name1 ])
            y= list(n.index)
            new = input('Enter new name: ').title()
            contact_data['Name'].loc[y[0]] = new

            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return


        elif num1 == 2:

            update_numbers()

        elif num1 == 3:

            name1 = input("\nEmail: ").title()
            print("\n")
            n = contact_data[contact_data.Email == name1 ]
            y= list(n.index)
            new = input('Enter new name: ').title()
            contact_data['Email'].loc[y[0]] = new

            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return


        elif num1 == 4:

            name1 = input("\nNickName: ").title()
            print("\n")
            n = (contact_data[contact_data.NickName == name1 ]) 
            y= list(n.index)
            new = input('Enter new name: ').title()
            contact_data['NickName'].loc[y[0]] = new

            print(''' 
            Press 1 to go back to Menu
            Press 2 to Retry''')
            input12 = int(input("\nOption: "))
            if input12 == 1:
                return
            if input12 == 2:
                continue
            else:
                print('Invalid Input\n')
                print('''
                Press 1 to Retry 
                Press 2 to go back to Menu ''')
                input12 = int(input("\nOption: "))
                if input12 == 1:
                    continue
                if input12 == 2:
                    print("Thank you!!!")
                    return

        else:
            print('''
            .....Invalid input......
            .....Please try Again.... ''')
            print('')
            print('''
                Press 1 to Retry 
                Press 2 to go back to Menu''')

            input12 = int(input("\nOption: "))
            if input12 == 1:
                continue           # to return to same function 
            if input12 == 2:
                print('Thank you!!!')
                return             # to return to menu function

# %%
def Contact_Book():
    flag = 1
    print('''
        .....Welcome to Contact Book Mangement.....
        ...........To Open Press Y/N..............
        ''')
    open1 = input('Y/N: ').title()
    if open1 == 'Y':
        while flag:
            print('''
            To Open Contact Book                 Press 1
            To Add New Contact                   Press 2
            To Search Contact                    Press 3
            To Update Name/Number/Email/NickName Press 4
            To Delete Contact                    Press 5
            To Exit                              Press 0
            ''')
            Option1 = int(input('Option: '))
            if Option1 == 1:
                print(contact_data)

            elif Option1 == 2:
                add_details()

            elif Option1 == 3:
                search_data()

            elif Option1 == 4:
                update_data()

            elif Option1 == 5:
                delete_data()

            else:
                print('Thank You!!!!!!')
                break

    else:
        print('Thank You!!!!!!')

# %%
Contact_Book()
contact_data.to_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Contact.csv')
# Out:
#         .....Welcome to Contact Book Mangement.....
#         ...........To Open Press Y/N..............
#
# Y/N: y
#
#             To Open Contact Book                 Press 1
#             To Add New Contact                   Press 2
#             To Search Contact                    Press 3
#             To Update Name/Number/Email/NickName Press 4
#             To Delete Contact                    Press 5
#             To Exit                              Press 0
#
# Option: 1
#      Name Number Number1 Number2    Email NickName
# 0  Akshat      1       2       3  Abc@123     Akku
#
#             To Open Contact Book                 Press 1
#             To Add New Contact                   Press 2
#             To Search Contact                    Press 3
#             To Update Name/Number/Email/NickName Press 4
#             To Delete Contact                    Press 5
#             To Exit                              Press 0
